# %% [markdown]
# <a href="https://colab.research.google.com/github/santabanta-bro/santabanta-bro/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = input(int(12))
print(a)
# Out:
# 122
# 2
